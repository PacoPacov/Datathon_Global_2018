# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
paco_data2.dropna(inplace=True)

# %%
paco_data2.head(30)
# Out:
#                    machine_name  drive_gear_V_eff  drive_gear_a_max  \
# date_measurement_f
# 2016-09-02                 RBG1            1.6164         1334.4815
# 2016-09-03                  NaN               NaN               NaN
# 2016-09-04                  NaN               NaN               NaN
# 2016-09-05                  NaN               NaN               NaN
# 2016-09-06                 RBG1            1.9335         1384.7760
# 2016-09-07                 RBG1            1.8736         1350.5540
# 2016-09-08                 RBG1            2.0121         1329.8515
# 2016-09-08                 RBG7            1.1688         1661.1080
# 2016-09-09                 RBG1            2.0060         1596.2396
# 2016-09-09                 RBG7            1.7682         1887.9280
# 2016-09-10                  NaN               NaN               NaN
# 2016-09-11                  NaN               NaN               NaN
# ...

# %%
paco_data2[]

# %%
## Import the sample data
## clock the time for import

tic = time.time()

of = pd.read_csv("Official_Failures.csv", parse_dates = [0])

tac = time.time()

diff = tac - tic

print("Time imprt had taken {a:.2f} seconds".format(a = diff))
# Out:
# Time imprt had taken 0.01 seconds

# %%
of.dtypes
# Out:
# Date                   datetime64[ns]
# Machine                        object
# drive_wheel_V_eff               int64
# drive_wheel_a_max               int64
# idle_wheel_V_eff                int64
# idle_wheel_a_max                int64
# drive_gear_V_eff                int64
# drive_gear_a_max                int64
# drive_motor_V_eff               int64
# drive_motor_a_max               int64
# lifting_gear_V_eff              int64
# lifting_gear_a_max              int64
# lifting_motor_V_eff             int64
# lifting_motor_a_max             int64
# dtype: object

# %%
rbg7_2.dtypes
# Out:
# drive_gear_V_eff       float64
# drive_gear_a_max       float64
# drive_motor_V_eff      float64
# drive_motor_a_max      float64
# drive_wheel_V_eff      float64
# drive_wheel_a_max      float64
# idle_wheel_V_eff       float64
# idle_wheel_a_max       float64
# lifting_gear_V_eff     float64
# lifting_gear_a_max     float64
# lifting_motor_V_eff    float64
# lifting_motor_a_max    float64
# cluster                float64
# dtype: object

# %%
rbg7_2 = dates_empty_df.merge(rbg7, how = 'outer',\
                                                      left_index = True, \
                                                     right_on = 'date_measurement_f').set_index('date_measurement_f')

# %%
X_train = paco_data2[paco_data2.machine_name =='RBG7'].iloc[:,2:]

# %%
sc_X = StandardScaler()
X_train_1 = sc_X.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-da24f64bc323> in <module>()
#       1 sc_X = StandardScaler()
# ----> 2 X_train_1 = sc_X.fit_transform(X_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# ...

# %%
plt.figure(figsize = (20,10))
plt.scatter(X_train_1[paco_data2["cluster"] == 0, 0], X_train_1[paco_data2["cluster"] == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X_train_1[paco_data2["cluster"] == 1, 0], X_train_1[paco_data2["cluster"] == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X_train_1[paco_data2["cluster"] == 2, 0], X_train_1[paco_data2["cluster"] == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X_train_1[paco_data2["cluster"] == 3, 0], X_train_1[paco_data2["cluster"] == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
#plt.scatter(X_train_1[paco_data2["cluster"] == 4, 0], X_train_1[paco_data2["cluster"] == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
#plt.scatter(X_train_1[paco_data2["cluster"] == 5, 0], X_train_1[paco_data2["cluster"] == 5, 1], s = 100, c = 'pink', label = 'Cluster 6')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-c4532c66a8ba> in <module>()
#       1 plt.figure(figsize = (20,10))
# ----> 2 plt.scatter(X_train_1[paco_data2["cluster"] == 0, 0], X_train_1[paco_data2["cluster"] == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
#       3 plt.scatter(X_train_1[paco_data2["cluster"] == 1, 0], X_train_1[paco_data2["cluster"] == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
#       4 plt.scatter(X_train_1[paco_data2["cluster"] == 2, 0], X_train_1[paco_data2["cluster"] == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
#       5 plt.scatter(X_train_1[paco_data2["cluster"] == 3, 0], X_train_1[paco_data2["cluster"] == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
#
# NameError: name 'X_train_1' is not defined

# %%
rbg7_3 = of.merge(rbg7_2, how = 'outer', left_on = 'Date', right_index = True)

# %%
rbg7_3.keys()
# Out:
# Index(['Date', 'Machine', 'drive_wheel_V_eff_x', 'drive_wheel_a_max_x',
#        'idle_wheel_V_eff_x', 'idle_wheel_a_max_x', 'drive_gear_V_eff_x',
#        'drive_gear_a_max_x', 'drive_motor_V_eff_x', 'drive_motor_a_max_x',
#        'lifting_gear_V_eff_x', 'lifting_gear_a_max_x', 'lifting_motor_V_eff_x',
#        'lifting_motor_a_max_x', 'drive_gear_V_eff_y', 'drive_gear_a_max_y',
#        'drive_motor_V_eff_y', 'drive_motor_a_max_y', 'drive_wheel_V_eff_y',
#        'drive_wheel_a_max_y', 'idle_wheel_V_eff_y', 'idle_wheel_a_max_y',
#        'lifting_gear_V_eff_y', 'lifting_gear_a_max_y', 'lifting_motor_V_eff_y',
#        'lifting_motor_a_max_y', 'cluster'],
#       dtype='object')

# %%
rbg7_3['drive_wheel_V_eff_x'].tail()
# Out:
# 25   NaN
# 25   NaN
# 25   NaN
# 25   NaN
# 25   NaN
# Name: drive_wheel_V_eff_x, dtype: float64

# %%
for i in ['drive_wheel_V_eff_x', 'drive_wheel_a_max_x',
       'idle_wheel_V_eff_x', 'idle_wheel_a_max_x', 'drive_gear_V_eff_x',
       'drive_gear_a_max_x', 'drive_motor_V_eff_x', 'drive_motor_a_max_x',
       'lifting_gear_V_eff_x', 'lifting_gear_a_max_x', 'lifting_motor_V_eff_x',
       'lifting_motor_a_max_x']:
    rbg7_3[i].fillna(0, inplace = True)

# %%
rbg7_3['drive_wheel_V_eff_x'].value_counts()
# Out:
# 0.0    682
# 1.0     26
# Name: drive_wheel_V_eff_x, dtype: int64

# %%
y = rbg7_3['drive_wheel_V_eff_x']
X = rbg7_3.drop(['drive_wheel_V_eff_x', 'Date', 'Machine', 'cluster'], axis = 1)

# %%
for i in X.keys():
    X.fillna(0, inplace = True)

# %%
smt = SMOTE()
X_enhanced, y_enhanced = smt.fit_sample(X, y)

# %%
y_enhanced = pd.DataFrame(y_enhanced)

# %%
y_enhanced[0].value_counts()
# Out:
# 0.0    682
# 1.0    682
# Name: 0, dtype: int64

# %%
X_enhanced = pd.DataFrame(X_enhanced)

# %%
X_enhanced.keys()
# Out:
# RangeIndex(start=0, stop=23, step=1)
